# %%
import pandas as pd
from sqlalchemy import create_engine

# Replace the following placeholders with your actual database credentials
username = 'postgres'
password = 1234
hostname = 'localhost'
port = '5432'  # Default PostgreSQL port
database = 'House'

# Create an engine instance
engine = create_engine(f'postgresql://{username}:{password}@{hostname}:{port}/{database}')

# Write a query to load data from the 'houses' table
query = 'SELECT * FROM houses'

# Load the dataset into a pandas dataframe
df = pd.read_sql(query, engine)

# Display the first few rows of the dataframe
print(df.head(50))
# Out:
#     id             address          city state zip_code   price owner_id  \
# 0    1    145 Maple Street     Smalltown    ST     1234  250000       o1
# 1    2      456 Oak Avenue       Bigcity    BC     5678  450000       o2
# 2    3       789 Pine Road    Middletown    MT     9101  320000       o3
# 3    4      101 Birch Lane    Townsville    TS     2345  300000       o4
# 4    5    202 Cedar Street   Villagetown    VT     6789  400000       o5
# 5    6    303 Spruce Drive    Hamletburg    HB     3456  350000       o6
# 6    7      404 Elm Street     Cityplace    CP     7890  500000       o7
# 7    8      505 Ash Avenue  Boroughville    BV     4567  375000       o8
# 8    9       11 Rodeo Lane     Cityplace    MT     9101  250000       o9
# 9   10  501 Foxglove Drive       Bigcity    WS     3136   51000      o11
# 10  11     94 Cedar Avenue    Hamletburg    VT     6789   75000      o12
# 11  12     52 Berry Avenue         Bronx    BC     5678   90000      o10
# 12  13   416 Orange Street       Alabama    BV     4567  261000      o15
# 13  14     131 White Birch         Bronx    WS     3136   65000      o13
# 14  15    971 Jackson Lane     Smalltown    WS     3136  105000      o14
# 15  16    145 Maple Street     Smalltown    ST     1234  250000       o1
# 16  17      456 Oak Avenue       Bigcity    BC     5678  450000       o2
# 17  18       789 Pine Road    Middletown    MT     9101  320000       o3
# 18  19      101 Birch Lane    Townsville    TS     2345  300000       o4
# 19  20    202 Cedar Street   Villagetown    VT     6789  400000       o5
# 20  21    303 Spruce Drive    Hamletburg    HB     3456  350000       o6
# 21  22      404 Elm Street     Cityplace    CP     7890  500000       o7
# 22  23      505 Ash Avenue  Boroughville    BV     4567  375000       o8
# 23  24       11 Rodeo Lane     Cityplace    MT     9101  250000       o9
# 24  25  501 Foxglove Drive       Bigcity    WS     3136   51000      o11
# 25  26     94 Cedar Avenue    Hamletburg    VT     6789   75000      o12
# 26  27     52 Berry Avenue         Bronx    BC     5678   90000      o10
# 27  28   416 Orange Street       Alabama    BV     4567  261000      o15
# 28  29     131 White Birch         Bronx    WS     3136   65000      o13
# 29  30    971 Jackson Lane     Smalltown    WS     3136  105000      o14
#
#     mortgage
# 0       1000
# 1       3000
# 2          0
# 3     200000
# 4      35000
# 5      15400
# 6      25000
# 7       4500
# 8        100
# 9       2800
# 10      6900
# 11      8300
# 12      1700
# 13      3570
# 14      5500
# 15      1000
# 16      3000
# 17         0
# 18    200000
# 19     35000
# 20     15400
# 21     25000
# 22      4500
# 23       100
# 24      2800
# 25      6900
# 26      8300
# 27      1700
# 28      3570
# 29      5500
